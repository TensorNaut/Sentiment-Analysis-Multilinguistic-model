# %%
pip install deep_translator
# Out:
# Collecting deep_translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (4.11.2)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep_translator) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2023.7.22)
# Installing collected packages: deep_translator
# Successfully installed deep_translator-1.11.4

# %%
pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 974.6 kB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2023.7.22)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
import codecs
from deep_translator import GoogleTranslator
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

def analyze_sentiment(text):
    translated_text = GoogleTranslator(source='auto', target='en').translate(text)
    analyzer = SentimentIntensityAnalyzer()
    sentiment_dict = analyzer.polarity_scores(translated_text)

    print("\nTranslated Sentence =", translated_text, "\nDictionary =", sentiment_dict)
    if sentiment_dict['compound'] >= 0.05:
        print("It is a Positive Sentence")
    elif sentiment_dict['compound'] <= -0.05:
        print("It is a Negative Sentence")
    else:
        print("It is a Neutral Sentence")

# Option for user input or file upload
print("Choose an option:")
print("1. Enter text")
print("2. Upload a file")

option = input("Enter the option (1 or 2): ")

if option == '1':
    # User input
    lines = []
    print("Enter text. Press Enter on an empty line to finish:")
    while True:
        line = input()
        if not line:
            break
        lines.append(line)

    for line in lines:
        analyze_sentiment(line)

elif option == '2':
    # File upload
    file_path = input("Enter the path of the file: ")
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            analyze_sentiment(line)
else:
    print("Invalid option. Please select 1 or 2.")
# Out:
# Choose an option:
# 1. Enter text
# 2. Upload a file
# Enter the option (1 or 2): 2
# Enter the path of the file: /content/Marathi_Datset.csv
#
# Translated Sentence = Nice!! Weee!! Visitors!
# Dictionary = {'neg': 0.0, 'neu': 0.335, 'pos': 0.665, 'compound': 0.6083}
# It is a Positive Sentence
#
# Translated Sentence = I feel like everyone here hates me
# Dictionary = {'neg': 0.279, 'neu': 0.481, 'pos': 0.24, 'compound': -0.1027}
# It is a Negative Sentence
#
# Translated Sentence = "Would love to, but I'm at school and myspace is completely blocked"
# Dictionary = {'neg': 0.197, 'neu': 0.637, 'pos': 0.166, 'compound': -0.1254}
# It is a Negative Sentence
#
# Translated Sentence = And all of that shortly after the last clue
# Dictionary = {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It is a Neutral Sentence
#
# Translated Sentence = what did you get I have a fine day.. haven't done anything yet. Going to my stepsister soon though!
# Dictionary = {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'compound': 0.2714}
# It is a Positive Sentence
#
# Translated Sentence = My bike was put on hold...should have known that....oh total bummer
# Dictionary = {'neg': 0.224, 'neu': 0.776, 'pos': 0.0, 'compound': -0.4391}
# It is a Negative Sentence
#
# Translated Sentence = i check We didn't win
# Dictionary = {'neg': 0.434, 'neu': 0.566, 'pos': 0.0, 'compound': -0.4717}
# It is a Negative Sentence
#
# Translated Sentence = .. and you're on twitter! Are you so bored of the pub?
# Dictionary = {'neg': 0.216, 'neu': 0.784, 'pos': 0.0, 'compound': -0.4648}
# It is a Negative Sentence
#
# Translated Sentence = "I'm in VA for the weekend, my youngest son turns 2 tomorrow......it makes me so sad, he's getting so big, check out my twpics"
# Dictionary = {'neg': 0.148, 'neu': 0.852, 'pos': 0.0, 'compound': -0.6113}
# It is a Negative Sentence
#
# Translated Sentence = This socket is coming out I think my phone hole is not virgin. How loose is that... :'(
# Dictionary = {'neg': 0.151, 'neu': 0.756, 'pos': 0.093, 'compound': -0.3045}
# It is a Negative Sentence
#
# Translated Sentence = "Too hot today =_= don't like it and I hate my new schedule, such a bad week"
# Dictionary = {'neg': 0.399, 'neu': 0.601, 'pos': 0.0, 'compound': -0.8523}
# It is a Negative Sentence
#
# Translated Sentence = miss you
# Dictionary = {'neg': 0.615, 'neu': 0.385, 'pos': 0.0, 'compound': -0.1531}
# It is a Negative Sentence
#
# Translated Sentence = Cramps .
# Dictionary = {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It is a Neutral Sentence
#
# Translated Sentence = You didn't say hi or answer my questions yesterday but nice songs.
# Dictionary = {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.5719}
# It is a Positive Sentence
#
# Translated Sentence = "I'm going into spiritual stagnation, my ego is exploding! I realize now, I'm not that great. And I'm okay with that."
# Dictionary = {'neg': 0.146, 'neu': 0.776, 'pos': 0.078, 'compound': -0.3991}
# It is a Negative Sentence
#
# Translated Sentence = stupid storm No river for us tonight
# Dictionary = {'neg': 0.528, 'neu': 0.472, 'pos': 0.0, 'compound': -0.6808}
# It is a Negative Sentence
#
# Translated Sentence = My dead grandfather pays more attention to me than you do
# Dictionary = {'neg': 0.301, 'neu': 0.699, 'pos': 0.0, 'compound': -0.6486}
# It is a Negative Sentence
#
# Translated Sentence = "...requires minor treatment, bad. AHHH.....gimme money gibbers"
# Dictionary = {'neg': 0.368, 'neu': 0.632, 'pos': 0.0, 'compound': -0.5423}
# It is a Negative Sentence
#
# Translated Sentence = going to sleep
# Dictionary = {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It is a Neutral Sentence
#
# Translated Sentence = you lame go make me breakfast!!
# Dictionary = {'neg': 0.404, 'neu': 0.596, 'pos': 0.0, 'compound': -0.5242}
# It is a Negative Sentence
#
# Translated Sentence = That is very nice
# Dictionary = {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.4754}
# It is a Positive Sentence
#
# Translated Sentence = "Hey guys, don't you just hate sitting on the floor haha, I'm just sitting eating an apple and watching death note (some anime)"
# Dictionary = {'neg': 0.13, 'neu': 0.669, 'pos': 0.201, 'compound': 0.2728}
# It is a Positive Sentence
#
# Translated Sentence = "Yes, the second ScarePoint Coding Sunday"
# Dictionary = {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.4019}
# It is a Positive Sentence
#
# Translated Sentence = Check out who I found for you ---> http://twitter.com/DJT2009
# Dictionary = {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It is a Neutral Sentence
#
# Translated Sentence = "No AC, fan doesn't go our way...we sweat in the humid sun"
# Dictionary = {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.3182}
# It is a Positive Sentence
#
# Translated Sentence = Guess it depends if you want to be on the jury
# Dictionary = {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.0772}
# It is a Positive Sentence
#
# Translated Sentence = Mickey DS resorted to eating alone.
# Dictionary = {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.25}
# It is a Negative Sentence
#
# Translated Sentence = "A wrong gothy chick looking at me, sorry I don't go to Camden and I like pop-punk and Jimmy It World"
# Dictionary = {'neg': 0.177, 'neu': 0.723, 'pos': 0.1, 'compound': -0.2263}
# It is a Negative Sentence
#
# Translated Sentence = Did it ask for your Twitter ID? Your sun sign?
# Dictionary = {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It is a Neutral Sentence
#
# Translated Sentence = Where did you go!
# Dictionary = {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It is a Neutral Sentence
#
# Translated Sentence = Watching Body of Lies...good movie
# Dictionary = {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It is a Neutral Sentence
#
# Translated Sentence = Happy Mother's Day my xoxo
# Dictionary = {'neg': 0.0, 'neu': 0.28, 'pos': 0.72, 'compound': 0.8271}
# It is a Positive Sentence
#
# Translated Sentence = So I really need to put the laptop down and get ready for the shindig... but I've missed my TwitterLoves all day.
# Dictionary = {'neg': 0.114, 'neu': 0.815, 'pos': 0.071, 'compound': -0.2617}
# It is a Negative Sentence
#
# Translated Sentence = I'm sorry, at least it's Friday?
# Dictionary = {'neg': 0.206, 'neu': 0.794, 'pos': 0.0, 'compound': -0.0772}
# It is a Negative Sentence
#
# Translated Sentence = "I feel bad every time I print, I use 200 new papers"
# Dictionary = {'neg': 0.241, 'neu': 0.759, 'pos': 0.0, 'compound': -0.5423}
# It is a Negative Sentence
#
# Translated Sentence = 4n? Never heard of ma rog esti beat acum? You tweet a lot
# Dictionary = {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It is a Neutral Sentence
#
# Translated Sentence = I always forget something when I travel. I'm at Newark Airport.
# Dictionary = {'neg': 0.16, 'neu': 0.84, 'pos': 0.0, 'compound': -0.2263}
# It is a Negative Sentence
#
# Translated Sentence = Should have left the car and gone home! I need someone to bail me out with petrol! Shining light
# Dictionary = {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It is a Neutral Sentence
#
# Translated Sentence = I'm just updating this so Brett's phone beeps but really.. looking at wedding stuff. Again.for the next five months.
# Dictionary = {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It is a Neutral Sentence
#
# Translated Sentence = "Hello. I agree! Babies should run with joy, not break down in tears."
# Dictionary = {'neg': 0.103, 'neu': 0.541, 'pos': 0.356, 'compound': 0.69}
# It is a Positive Sentence
#
# Translated Sentence = Hope you have fun at the club
# Dictionary = {'neg': 0.0, 'neu': 0.446, 'pos': 0.554, 'compound': 0.7351}
# It is a Positive Sentence
#
# Translated Sentence = I want a new one for my birthday until I miss my old phone it works great...
# Dictionary = {'neg': 0.076, 'neu': 0.667, 'pos': 0.257, 'compound': 0.5859}
# It is a Positive Sentence
#
# Translated Sentence = Sounds like SG is awesome
# Dictionary = {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'compound': 0.765}
# It is a Positive Sentence
#
# Translated Sentence = "I'm really sorry, I know how this life feels to you"
# Dictionary = {'neg': 0.137, 'neu': 0.863, 'pos': 0.0, 'compound': -0.1513}
# It is a Negative Sentence
#
# Translated Sentence = not happy
# Dictionary = {'neg': 0.75, 'neu': 0.25, 'pos': 0.0, 'compound': -0.4585}
# It is a Negative Sentence
#
# Translated Sentence = Watching an acoustic performance! And in the mood for a good 'Friends' episode! I miss that show
# Dictionary = {'neg': 0.072, 'neu': 0.631, 'pos': 0.297, 'compound': 0.717}
# It is a Positive Sentence
#
# Translated Sentence = I would swing from one to the other.
# Dictionary = {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It is a Neutral Sentence
#
# Translated Sentence = I'm so tired...and sleepless.
# Dictionary = {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It is a Neutral Sentence
#
# Translated Sentence = thanks ennio
# Dictionary = {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# It is a Positive Sentence
#
# Translated Sentence = You take me and bring me with you to Kellslodge House.
# Dictionary = {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It is a Neutral Sentence
